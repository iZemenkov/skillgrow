# %% [markdown]
# # Извлечение навыков из поля `description`

# %% [markdown]
# ## Импорт библиотек

# %%
import re
import pandas as pd
import numpy as np

from pathlib import Path
from itertools import chain

# %%
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
import torch
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

MODEL_ID = "ai-forever/sbert_large_nlu_ru"
device = "cuda" if torch.cuda.is_available() else "cpu"
model = SentenceTransformer(MODEL_ID, device=device)

model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 1024, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
# Хранилище обработанных данных:

PROCESSED_DIR = Path('../data/processed')
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Работа с данными

# %%
df = pd.read_csv("https://izemenkov.github.io/skillgrow/data/raw_data/vacancies_master.csv")

# Оставляем только описание
texts = df["description"].dropna().copy()

# Простейшая очистка
def clean_text(t):
    t = re.sub(r"<.*?>", " ", t)         # убираем html разметку, если сохранилась
    t = re.sub(r"[^а-яА-Яa-zA-Z0-9+#/\. ]", " ", t)  # убираем спецсимволы
    t = re.sub(r"\s+", " ", t)
    return t.lower().strip()

texts = texts.apply(clean_text)

df["clean_text"] = texts
df.head()
# Out:
#           id                                         name             area  \
# 0  127202494                 ML-аналитик / Data Scientist           Москва
# 1  127244399                 Аналитик данных/Data Analyst  Нижний Новгород
# 2  126209623        Стажер, Data Analyst / Data Scientist           Москва
# 3  127192646  Младший аналитик данных/Junior Data Analyst           Москва
# 4  126562421          Junior Data Analyst/Аналитик данных           Казань
#
#            experience                                         key_skills  \
# 0           Нет опыта                                                NaN
# 1           Нет опыта            Python, SQL, Базы данных, Анализ данных
# 2           Нет опыта  Python, pandas, Numpy, ООП, Алгоритмы и структ...
# 3  От 1 года до 3 лет  Python, SQL, Аналитическое мышление, Исследова...
# 4           Нет опыта                                                NaN
#
#                                          description  \
# 0  Обязанности:  Моделирование клиентского поведе...
# 1  Ищем специалиста, готового влиться в команду п...
# 2  В сегодняшней бизнес-среде компаниям необходим...
# 3  Mediascope – исследовательская компания, котор...
# 4  Привет! Мы команда разработчиков платформы You...
#
#                                           clean_text
# 0  обязанности моделирование клиентского поведени...
# 1  ищем специалиста готового влиться в команду пр...
# 2  в сегодняшней бизнес среде компаниям необходим...
# 3  mediascope исследовательская компания которая ...
# 4  привет мы команда разработчиков платформы youn...

# %%
# Создадим список навыков
df["skills_list"] = df["key_skills"].fillna("").apply(lambda x: [s.strip().lower() for s in x.split(",") if s.strip()])

# объединяем все навыки в один список
all_skills = list(chain.from_iterable(df["skills_list"]))

skill_freq = (
    pd.Series(all_skills)
    .value_counts()
    .reset_index()
    .rename(columns={"index": "skill", 0: "count"})
)

skill_freq.head(20)
# Out:
#                         skill  count
# 0                      python    205
# 1                         sql    151
# 2                      pandas     50
# 3                     pytorch     42
# 4                          ml     40
# 5               анализ данных     39
# 6                    big data     38
# 7   математическая статистика     31
# 8                       numpy     28
# 9         визуализация данных     27
# 10                   power bi     26
# 11                        nlp     26
# 12                     hadoop     24
# 13           machine learning     22
# 14              deep learning     21
# 15               data science     21
# 16                 tensorflow     21
# 17                 clickhouse     18
# 18                     mlflow     17
# 19                        git     17

# %%
# Проверим на "шум"

# Навыки короче 2 символов
skill_freq[skill_freq.skill.str.len() < 2]

# Видим только r, оставим
# Out:
#    skill  count
# 66     r      5

# %%
# Навыки, встречающиеся менее 3 раз
skill_freq[skill_freq["count"] < 3]
# Out:
#                        skill  count
# 94                       vba      2
# 95       обучение и развитие      2
# 96             разработка по      2
# 97               power query      2
# 98                      json      2
# ..                       ...    ...
# 327            проактивность      1
# 328                 qlikview      1
# 329         программирование      1
# 330                       ии      1
# 331  проведение тестирований      1
#
# [238 rows x 2 columns]

# %% [markdown]
# Навыки, встречающиеся менее двух раз уберем. Среди них, визуально, есть и значащие, но, зачастую, они являются подразделами более частых навыков. Попробуем обойтись без них

# %%
# убираем навыки частотой < 2 и навык it, как незначащий
skill_vocab = skill_freq[(skill_freq["count"] >= 3) & (skill_freq["skill"] != 'it')]["skill"].tolist()
len(skill_vocab), skill_vocab[:30]
# Out:
# (93,
#  ['python',
#   'sql',
#   'pandas',
#   'pytorch',
#   'ml',
#   'анализ данных',
#   'big data',
#   'математическая статистика',
#   'numpy',
#   'визуализация данных',
#   'power bi',
#   'nlp',
#   'hadoop',
#   'machine learning',
#   'deep learning',
#   'data science',
#   'tensorflow',
#   'clickhouse',
#   'mlflow',
#   'git',
#   'scikit-learn',
#   'postgresql',
#   'docker',
#   'etl',
#   'ms excel',
#   'cv',
#   'pyspark',
#   'llm',
#   'data analysis',
#   'аналитическое мышление'])

# %%
# Извлекаем навыки с помощью полученного списка:

df["clean_text"] = df["description"].fillna("").str.lower()

def extract_from_text(text, vocab):
    results = []
    for s in vocab:
        if len(s) == 1:
            # skill состоит из 1 буквы: ищем только как отдельное слово
            # пример: r → ищем ` r ` или начало/конец строки
            pattern = r'\b' + re.escape(s) + r'\b'
            if re.search(pattern, text):
                results.append(s)

        else:
            # обычные навыки: разрешаем подстроки
            if s in text:
                results.append(s)

    return results

df["skills_from_description"] = df["clean_text"].apply(lambda t: extract_from_text(t, skill_vocab))

# %%
# Проверим покрытие
coverage = (df["skills_from_description"].apply(len) > 0).mean()
print(f"Доля вакансий с навыками из описания: {coverage:.1%}")

skills_flat = list(chain.from_iterable(df["skills_from_description"]))
pd.Series(skills_flat).value_counts().head(20)
# Out:
# Доля вакансий с навыками из описания: 99.8%
# python          420
# sql             344
# ml              323
# pandas          191
# pytorch         151
# numpy           148
# llm             139
# аналитика       131
# nlp             128
# git             124
# spark           116
# docker          106
# api              99
# scikit-learn     79
# data science     76
# power bi         71
# clickhouse       71
# etl              70
# tableau          65
# pyspark          65
# Name: count, dtype: int64

# %% [markdown]
# Удалось добиться хорошего покрытия вакансий навыками.
# Теперь приедем все к единому полю навыков, с которым будем работать в дальнейшем

# %%
def unite_skills(row):
    s1 = row.get("skills_list", [])
    s2 = row.get("skills_from_description", [])
    # объединяем, чистим и сортируем
    return sorted(set(map(str.lower, s1 + s2)))

df["final_skills"] = df.apply(unite_skills, axis=1)

# %%
# Смотрим частоты по финальному списку навыков

final_skills_flat = list(chain.from_iterable(df["final_skills"]))
pd.Series(final_skills_flat).value_counts().head(25)
# Out:
# python           438
# sql              359
# ml               325
# pandas           202
# pytorch          161
# numpy            157
# llm              140
# git              136
# аналитика        132
# nlp              129
# spark            121
# docker           111
# api               99
# data science      88
# scikit-learn      86
# hadoop            79
# power bi          77
# clickhouse        77
# анализ данных     76
# pyspark           72
# etl               71
# tensorflow        68
# matplotlib        67
# tableau           66
# big data          66
# Name: count, dtype: int64

# %%
# Смотрим частотность навыков, исходя из опыта
exploded = df.explode("final_skills")
grp = exploded.groupby(["experience", "final_skills"]).size().reset_index(name="count")
grp.sort_values("count", ascending=False).groupby("experience").head(15)
# Out:
#              experience               final_skills  count
# 445       От 3 до 6 лет                     python    236
# 466       От 3 до 6 лет                        sql    190
# 415       От 3 до 6 лет                         ml    185
# 230  От 1 года до 3 лет                     python    147
# 242  От 1 года до 3 лет                        sql    123
# 446       От 3 до 6 лет                    pytorch    100
# 434       От 3 до 6 лет                     pandas     98
# 200  От 1 года до 3 лет                         ml     96
# 410       От 3 до 6 лет                        llm     84
# 428       От 3 до 6 лет                      numpy     80
# 426       От 3 до 6 лет                        nlp     78
# 222  От 1 года до 3 лет                     pandas     70
# 377       От 3 до 6 лет                     docker     68
# 385       От 3 до 6 лет                        git     67
# 465       От 3 до 6 лет                      spark     67
# 491       От 3 до 6 лет                  аналитика     67
# 215  От 1 года до 3 лет                      numpy     57
# 267  От 1 года до 3 лет                  аналитика     56
# 357       От 3 до 6 лет                        api     56
# 392       От 3 до 6 лет                     hadoop     49
# 176  От 1 года до 3 лет                        git     49
# 459       От 3 до 6 лет               scikit-learn     47
# 194  От 1 года до 3 лет                        llm     45
# 231  От 1 года до 3 лет                    pytorch     44
# 143  От 1 года до 3 лет                        api     41
# 212  От 1 года до 3 лет                        nlp     39
# 264  От 1 года до 3 лет              анализ данных     38
# 170  От 1 года до 3 лет                     docker     35
# 40          Более 6 лет                         ml     35
# 241  От 1 года до 3 лет                      spark     35
# 54          Более 6 лет                     python     34
# 199  От 1 года до 3 лет                 matplotlib     32
# 64          Более 6 лет                        sql     30
# 49          Более 6 лет                     pandas     21
# 113           Нет опыта                     python     21
# 23          Более 6 лет                        git     18
# 120           Нет опыта                        sql     16
# 63          Более 6 лет                      spark     15
# 55          Более 6 лет                    pytorch     15
# 7           Более 6 лет                   big data     14
# 109           Нет опыта                     pandas     13
# 12          Более 6 лет               data science     13
# 52          Более 6 лет                   power bi     12
# 11          Более 6 лет                         cv     12
# 45          Более 6 лет                        nlp     12
# 18          Более 6 лет                        dwh     11
# 36          Более 6 лет                        llm     11
# 19          Более 6 лет                        etl     11
# 107           Нет опыта                      numpy     10
# 103           Нет опыта                         ml      9
# 111           Нет опыта                   power bi      7
# 83            Нет опыта                   big data      6
# 126           Нет опыта              анализ данных      5
# 121           Нет опыта                    tableau      5
# 127           Нет опыта                  аналитика      5
# 132           Нет опыта  математическая статистика      5
# 89            Нет опыта               data science      4
# 102           Нет опыта                 matplotlib      4
# 101           Нет опыта           machine learning      4
# 129           Нет опыта        визуализация данных      4

# %% [markdown]
# ### Выводы
#
# * Удалось добиться извлечения навыков из вакансий с хорошим покрытием (>99%)
# * Собрали ядро DS компетенций для рынка РФ
# | Навык                                  | Частота                                                           | Комментарий                             |
# | -------------------------------------- | ----------------------------------------------------------------- | --------------------------------------- |
# | **python**                             | 407                                                               | базовый рабочий язык                    |
# | **sql**                                | 333                                                               | must-have для аналитики и продакшена    |
# | **ml**                                 | 306                                                               | обобщающее, но отражает роль            |
# | **pandas / numpy**                     | 186 / 143                                                         | работа с табличными данными             |
# | **pytorch / tensorflow**               | 150 / 62                                                          | модели в проде, особенно pytorch        |
# | **nlp / llm**                          | 119 / 131                                                         | **всплеск из-за LLM тренда**, это важно |
# | **spark / hadoop / pyspark**           | 115 / 76 / 71                                                     | Big Data → всё чаще must-have           |
# | **docker / git / api**                 | 105 / 127 / 88                                                    | продакшен навыки                        |
# | **power bi / clickhouse / postgresql** | Power BI = BI для бизнеса; ClickHouse/PostgreSQL                  | инфраструктура                       |
#
#
# * Навыки против опыта показывают возможный карьерный трек специалиста:
#
# | Опыт          | Ключевые навыки                                              | Интерпретация                                |
# | ------------- | ------------------------------------------------------------ | -------------------------------------------- |
# | **Нет опыта** | python, sql, pandas, power bi                                | Вход с BI / аналитики ↔ стажировки           |
# | **1–3 года**  | python, sql, ml, pandas, nlp, numpy, docker                  | переход «анализ → модели → прототипирование» |
# | **3–6 лет**   | python, sql, llm, pytorch, spark, docker, clickhouse, hadoop | продакшн ML + Big Data + архитектура         |
# | **> 6 лет**   | python, sql, ml, big data, power bi, cv                      | роли "ведущий / архитектор / руководитель"   |
#
#
# MVP Системы рекомендаций может работать следующим образом:
#
# "Вы целитесь в позицию с опытом X. Средние навыки для этой зоны: ...
# У вас есть: ...
# Рекомендуем добрать: ..."

# %%
# Сохраним файл мастер-данных в ../data/processed
df_to_save = df[['id','name','area','experience','clean_text','final_skills']].rename(columns={'clean_text':'description'})

# %%
df_to_save
# Out:
#             id                                               name  \
# 0    127202494                       ML-аналитик / Data Scientist
# 1    127244399                       Аналитик данных/Data Analyst
# 2    126209623              Стажер, Data Analyst / Data Scientist
# 3    127192646        Младший аналитик данных/Junior Data Analyst
# 4    126562421                Junior Data Analyst/Аналитик данных
# ..         ...                                                ...
# 512  127525182              Data Analyst (Идентификация и трафик)
# 513  127549143        Middle Data Analyst / DA (Медийная реклама)
# 514  127499653  Эксперт (комплекс систем для управления data-п...
# 515  127549047             Data analyst middle (Медийная реклама)
# 516  127540589           Senior Data Scientist NLP/CV [Модерация]
#
#                 area          experience  \
# 0             Москва           Нет опыта
# 1    Нижний Новгород           Нет опыта
# 2             Москва           Нет опыта
# 3             Москва  От 1 года до 3 лет
# 4             Казань           Нет опыта
# ..               ...                 ...
# 512           Москва       От 3 до 6 лет
# 513           Москва       От 3 до 6 лет
# 514          Иркутск  От 1 года до 3 лет
# 515           Москва       От 3 до 6 лет
# 516           Москва         Более 6 лет
#
#                                            description  \
# 0    обязанности:  моделирование клиентского поведе...
# 1    ищем специалиста, готового влиться в команду п...
# 2    в сегодняшней бизнес-среде компаниям необходим...
# 3    mediascope – исследовательская компания, котор...
# 4    привет! мы команда разработчиков платформы you...
# ..                                                 ...
# 512  описание проекта: ит b2c — самая крупная экоси...
# 513  мы ищем middle data analyst / data engineer в ...
# 514  команда «apl витрины» дивизиона «розничное взы...
# 515  ит b2c — самая крупная экосистема в сбере. нас...
# 516  объединённая компания wildberries и russ — это...
#
#                                           final_skills
# 0    [etl, ml, mlflow, pandas, python, scikit-learn...
# 1    [dwh, python, sql, анализ данных, аналитика, б...
# 2    [big data, data science, git, ml, ms sql, nump...
# 3    [data science, dwh, jupyter notebook, python, ...
# 4      [numpy, pandas, power bi, python, sql, tableau]
# ..                                                 ...
# 512                 [apache spark, python, spark, sql]
# 513                      [clickhouse, etl, spark, sql]
# 514             [dwh, etl, greenplum, postgresql, sql]
# 515                           [python, sql, аналитика]
# 516  [anomaly detection, cv, deep learning, documen...
#
# [517 rows x 6 columns]

# %%
df_to_save.to_csv(PROCESSED_DIR / 'extracted_skills.csv', index=False)

# %% [markdown]
# ## Создание векторной базы вакансий (навыков и описаний)

# %%
df = df_to_save.copy(deep=True)

# %%
# Приведем к строкам поля описания и навыков

def list_to_text(x):
    if isinstance(x, (list, tuple, set)):
        return " ".join(map(str, x))
    if pd.isna(x):
        return ""
    return str(x)

df['final_skills'] = df['final_skills'].apply(list_to_text).fillna('')


df['description'] = df['description'].fillna("").astype(str)

# %%
def batched_encode(texts, batch_size=64, normalize=True):
    """Возвращает np.ndarray размера [N, D]."""
    texts = list(texts)  # на случай Series
    embs = []
    for i in tqdm(range(0, len(texts), batch_size)):
        batch = texts[i:i+batch_size]
        with torch.inference_mode():
            e = model.encode(
                batch,
                convert_to_numpy=True,
                normalize_embeddings=normalize
            )
        embs.append(e)
    return np.vstack(embs) if embs else np.zeros((0, model.get_sentence_embedding_dimension()), dtype=np.float32)

# %%
df
# Out:
#             id                                               name  \
# 0    127202494                       ML-аналитик / Data Scientist
# 1    127244399                       Аналитик данных/Data Analyst
# 2    126209623              Стажер, Data Analyst / Data Scientist
# 3    127192646        Младший аналитик данных/Junior Data Analyst
# 4    126562421                Junior Data Analyst/Аналитик данных
# ..         ...                                                ...
# 512  127525182              Data Analyst (Идентификация и трафик)
# 513  127549143        Middle Data Analyst / DA (Медийная реклама)
# 514  127499653  Эксперт (комплекс систем для управления data-п...
# 515  127549047             Data analyst middle (Медийная реклама)
# 516  127540589           Senior Data Scientist NLP/CV [Модерация]
#
#                 area          experience  \
# 0             Москва           Нет опыта
# 1    Нижний Новгород           Нет опыта
# 2             Москва           Нет опыта
# 3             Москва  От 1 года до 3 лет
# 4             Казань           Нет опыта
# ..               ...                 ...
# 512           Москва       От 3 до 6 лет
# 513           Москва       От 3 до 6 лет
# 514          Иркутск  От 1 года до 3 лет
# 515           Москва       От 3 до 6 лет
# 516           Москва         Более 6 лет
#
#                                            description  \
# 0    обязанности:  моделирование клиентского поведе...
# 1    ищем специалиста, готового влиться в команду п...
# 2    в сегодняшней бизнес-среде компаниям необходим...
# 3    mediascope – исследовательская компания, котор...
# 4    привет! мы команда разработчиков платформы you...
# ..                                                 ...
# 512  описание проекта: ит b2c — самая крупная экоси...
# 513  мы ищем middle data analyst / data engineer в ...
# 514  команда «apl витрины» дивизиона «розничное взы...
# 515  ит b2c — самая крупная экосистема в сбере. нас...
# 516  объединённая компания wildberries и russ — это...
#
#                                           final_skills
# 0         etl ml mlflow pandas python scikit-learn sql
# 1    dwh python sql анализ данных аналитика базы да...
# 2    big data data science git ml ms sql numpy pand...
# 3    data science dwh jupyter notebook python spark...
# 4             numpy pandas power bi python sql tableau
# ..                                                 ...
# 512                      apache spark python spark sql
# 513                           clickhouse etl spark sql
# 514                   dwh etl greenplum postgresql sql
# 515                               python sql аналитика
# 516  anomaly detection cv deep learning document oc...
#
# [517 rows x 6 columns]

# %%
skills_emb = batched_encode(df["final_skills"], batch_size=64)
desc_emb = batched_encode(df["description"], batch_size=64)


desc_emb.shape, skills_emb.shape  # (N, D), (N, D)
# Out:
# 100%|██████████| 9/9 [00:02<00:00,  4.38it/s]
# 100%|██████████| 9/9 [00:18<00:00,  2.06s/it]
# ((517, 1024), (517, 1024))

# %%
out = pd.DataFrame({
    "id": df_to_save["id"].astype(str),
    "desc_emb":  list(map(lambda v: v.astype(float).tolist(), desc_emb)),
    "skills_emb":list(map(lambda v: v.astype(float).tolist(), skills_emb)),
})
out.to_parquet("../data/processed/embeddings.parquet", index=False)
