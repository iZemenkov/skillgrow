# %% [markdown]
# # Работа с открытым API HeadHunter

# %% [markdown]
# **Цель:**
# отладка параметров запросов к HH, формат загружаемых данных

# %% [markdown]
# ## 1. Импорт библиотек и установка констант

# %%
import requests
import pandas as pd
import time
import datetime as dt

from pathlib import Path
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
# Создадим хранилище для сырых данных
RAW_DIR = Path('../data/raw_data')
RAW_DIR.mkdir(parents=True, exist_ok=True)

MASTER_PATH = Path("../data/raw_data/vacancies_master.csv")

MASTER_COLUMNS = [
    "id", "name", "area", "experience",
    "key_skills", "description"
]

# Эндпоинт поиска вакансий через API
BASE_URL = 'https://api.hh.ru/vacancies'


# Параметры поиска по умолчанию
DEFAULT_PARAMS = {"text":"name:(data analyst) OR name:(data scientist)",
                  "area":"113", # Россия
                  "per_page": 100, # вакансий на страницу
                  "page": 0, # номер страницы
                  "only_with_salary": False, # не только с указанной зарплатой
                  "search_field": "name", # поле для поиска текста
                  "date_from": None, "date_to": None # фильтры по дате
}

# %% [markdown]
# Создадим запрос с базовыми параметрами для проверки:

# %%
requests.get(BASE_URL, params=DEFAULT_PARAMS).json()
# Out:
# {'items': [{'id': '127202494',
#    'premium': False,
#    'name': 'ML-аналитик / Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-11-01T09:09:01+0300',
#    'created_at': '2025-11-01T09:09:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127202494',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/127202494?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/127202494',
#    'relations': [],
#    'employer': {'id': '55551',
#     'name': 'ЮНИСТРИМ БАНК',
#     'url': 'https://api.hh.ru/employers/55551',
#     'alternate_url': 'https://hh.ru/employer/55551',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/478320.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo/2355132.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/2355133.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=55551',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное владение Python, pandas, scikit-learn, MLflow. Опыт работы в DataSphere или аналогичных средах. Знание SQL и базовых принципов ETL. ',
#     'responsibility': 'Моделирование клиентского поведения, прогнозирование оттока. Работа в Yandex DataSphere, создание и тренировка ML-моделей. Подготовка данных для моделей (ETL-процессы...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '127244399',
#    'premium': False,
#    'name': 'Аналитик данных/Data Analyst',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '66',
#     'name': 'Нижний Новгород',
#     'url': 'https://api.hh.ru/areas/66'},
#    'salary': {'from': 90000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'salary_range': {'from': 90000,
#     'to': None,
#     'currency': 'RUR',
#     'gross': True,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': None},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-11-02T12:13:58+0300',
#    'created_at': '2025-11-02T12:13:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127244399',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/127244399?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/127244399',
#    'relations': [],
#    'employer': {'id': '9588971',
#     'name': 'РУССМАРКЕТ',
#     'url': 'https://api.hh.ru/employers/9588971',
#     'alternate_url': 'https://hh.ru/employer/9588971',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1416380.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7285176.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7285177.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9588971',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы аналитиком данных от 9 месяцев и выше. Развитое критическое и системное мышление, понимание основ теории вероятностей и математической...',
#     'responsibility': 'Работа в функциональной команде, нацеленной на развитие продаж. Работа с базами данных с целью оцифровки и разработки моделей прогнозирования. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_9', 'name': '9 часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '127192646',
#    'premium': False,
#    'name': 'Младший аналитик данных/Junior Data Analyst',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Двинцев',
#     'building': '12к1Б',
#     'lat': 55.796764,
#     'lng': 37.599013,
#     'description': None,
#     'raw': 'Москва, улица Двинцев, 12к1Б',
#     'metro': {'station_name': 'Марьина Роща',
#      'line_name': 'Люблинско-Дмитровская',
#      'station_id': '10.185',
#      'line_id': '10',
#      'lat': 55.793723,
#      'lng': 37.61618},
#     'metro_stations': [{'station_name': 'Марьина Роща',
#       'line_name': 'Люблинско-Дмитровская',
#       'station_id': '10.185',
#       'line_id': '10',
#       'lat': 55.793723,
#       'lng': 37.61618},
#      {'station_name': 'Савёловская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.128',
#       'line_id': '9',
#       'lat': 55.794054,
#       'lng': 37.587163},
#      {'station_name': 'Савёловская',
#       'line_name': 'Большая кольцевая линия',
#       'station_id': '97.685',
#       'line_id': '97',
#       'lat': 55.794054,
#       'lng': 37.587163}],
#     'id': '19253248'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-31T17:40:06+0300',
#    'created_at': '2025-10-31T17:40:06+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127192646',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': {'id': '33742',
#     'url': 'https://hh.ru/interview/33742?employerId=2739341'},
#    'url': 'https://api.hh.ru/vacancies/127192646?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/127192646',
#    'relations': [],
#    'employer': {'id': '2739341',
#     'name': 'Mediascope',
#     'url': 'https://api.hh.ru/employers/2739341',
#     'alternate_url': 'https://hh.ru/employer/2739341',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/966623.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/5484932.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/5484933.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2739341',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее профильное образование. Опыт чтения документации DWH. Уверенное владение SQL или Python. Умение использовать продвинутые функции Excel. Опыт работы с...',
#     'responsibility': 'Лаб тесты/тесты обновлений инструментов, приложений. Делаем эксперименты и анализ различных моделей совместно с командами RnD и Data Science, строим...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '127139735',
#    'premium': False,
#    'name': 'Junior Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Василисы Кожиной',
#     'building': '1',
#     'lat': 55.737502,
#     'lng': 37.504789,
#     'description': None,
#     'raw': 'Москва, улица Василисы Кожиной, 1',
#     'metro': {'station_name': 'Багратионовская',
#      'line_name': 'Филевская',
#      'station_id': '4.14',
#      'line_id': '4',
#      'lat': 55.743544,
#      'lng': 37.497042},
#     'metro_stations': [{'station_name': 'Багратионовская',
#       'line_name': 'Филевская',
#       'station_id': '4.14',
#       'line_id': '4',
#       'lat': 55.743544,
#       'lng': 37.497042},
#      {'station_name': 'Парк Победы',
#       'line_name': 'Арбатско-Покровская',
#       'station_id': '3.173',
#       'line_id': '3',
#       'lat': 55.735679,
#       'lng': 37.516865},
#      {'station_name': 'Парк Победы',
#       'line_name': 'Солнцевская',
#       'station_id': '133.470',
#       'line_id': '133',
#       'lat': 55.736478,
#       'lng': 37.514401},
#      {'station_name': 'Фили',
#       'line_name': 'МЦД-1',
#       'station_id': '131.703',
#       'line_id': '131',
#       'lat': 55.744263,
#       'lng': 37.514526}],
#     'id': '19724070'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-30T12:17:23+0300',
#    'created_at': '2025-10-30T12:17:23+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127139735',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/127139735?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/127139735',
#    'relations': [],
#    'employer': {'id': '1191643',
#     'name': 'IDF Eurasia',
#     'url': 'https://api.hh.ru/employers/1191643',
#     'alternate_url': 'https://hh.ru/employer/1191643',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1429135.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7336189.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7336190.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1191643',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Знание Python и ключевых библиотек (Pandas, Scikit-learn) для анализа данных и машинного обучения. Опыт написания SQL-запросов для извлечения...',
#     'responsibility': 'Участвовать в полном цикле разработки и эксплуатации скоринговых и предиктивных моделей под руководством старших коллег: от сбора данных и анализа...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126562421',
#    'premium': False,
#    'name': 'Junior Data Analyst/Аналитик данных',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '88', 'name': 'Казань', 'url': 'https://api.hh.ru/areas/88'},
#    'salary': {'from': 90000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'salary_range': {'from': 90000,
#     'to': None,
#     'currency': 'RUR',
#     'gross': True,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': {'id': 'MONTHLY', 'name': 'Раз в\xa0месяц'}},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-15T12:56:37+0300',
#    'created_at': '2025-10-15T12:56:37+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126562421',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126562421?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126562421',
#    'relations': [],
#    'employer': {'id': '5962259',
#     'name': 'Your CodeReview',
#     'url': 'https://api.hh.ru/employers/5962259',
#     'alternate_url': 'https://hh.ru/employer/5962259',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/5799555.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/5799557.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/5799558.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5962259',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Базовые знания SQL для работы с данными. Навыки работы с Excel/Google Таблицами (сводные таблицы, основные функции). Понимание основ статистики...',
#     'responsibility': 'Собирать и обрабатывать данные из различных источников для последующего анализа. Создавать визуализации и дашборды для мониторинтра ключевых метрик продукта. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#      'name': 'Можно сменами по\xa04-6\xa0часов в\xa0день'}],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_6', 'name': '6\xa0часов'},
#     {'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126209623',
#    'premium': False,
#    'name': 'Стажер, Data Analyst / Data Scientist',
#    'department': {'id': '201-201-itserv', 'name': 'Kept, ИТ-сервисы'},
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Ленинградский проспект',
#     'building': '34А',
#     'lat': 55.78531580767879,
#     'lng': 37.567994114085565,
#     'description': None,
#     'raw': 'Москва, Ленинградский проспект, 34А',
#     'metro': {'station_name': 'Динамо',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.34',
#      'line_id': '2',
#      'lat': 55.789704,
#      'lng': 37.558212},
#     'metro_stations': [{'station_name': 'Динамо',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.34',
#       'line_id': '2',
#       'lat': 55.789704,
#       'lng': 37.558212},
#      {'station_name': 'Петровский парк',
#       'line_name': 'Большая кольцевая линия',
#       'station_id': '97.599',
#       'line_id': '97',
#       'lat': 55.79233,
#       'lng': 37.55952}],
#     'id': '16628589'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-06T18:43:16+0300',
#    'created_at': '2025-10-06T18:43:16+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126209623',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126209623?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126209623',
#    'relations': [],
#    'employer': {'id': '201',
#     'name': 'Kept (Кэпт)',
#     'url': 'https://api.hh.ru/employers/201',
#     'alternate_url': 'https://hh.ru/employer/201',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1077254.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/5929645.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/5929646.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=201',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование или в том числе студент старших курсов в области математики, информатики в бизнесе и аналогичные. Хороший уровень Python...',
#     'responsibility': 'Применение продвинутых ИТ подходов на реальных проектах консалтинга. Разработка инструментов работы с данными, повышающими эффективность проектов. Внедрение новых подходов по...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': True,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126984712',
#    'premium': False,
#    'name': 'Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Космодамианская набережная',
#     'building': '52с1',
#     'lat': 55.732063,
#     'lng': 37.647235,
#     'description': None,
#     'raw': 'Москва, Космодамианская набережная, 52с1',
#     'metro': {'station_name': 'Павелецкая',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.101',
#      'line_id': '2',
#      'lat': 55.729741,
#      'lng': 37.638693},
#     'metro_stations': [{'station_name': 'Павелецкая',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.101',
#       'line_id': '2',
#       'lat': 55.729741,
#       'lng': 37.638693},
#      {'station_name': 'Павелецкая',
#       'line_name': 'Кольцевая',
#       'station_id': '5.102',
#       'line_id': '5',
#       'lat': 55.731414,
#       'lng': 37.636294}],
#     'id': '2753445'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-27T12:41:12+0300',
#    'created_at': '2025-10-27T12:41:12+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126984712',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126984712?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126984712',
#    'relations': [],
#    'employer': {'id': '1994',
#     'name': 'АДВ',
#     'url': 'https://api.hh.ru/employers/1994',
#     'alternate_url': 'https://hh.ru/employer/1994',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1461964.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7467466.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7467467.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1994',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (техническое, математическое). Владение Python (библиотеки pandas, numpy, re, sklearn, xgboost, prophet, plotly, matplotlib, seaborn). Опыт решения задач кластеризации...',
#     'responsibility': 'Проведение эконометрического моделирования в области Медиа и Рекламы: выявление зависимостей между рекламными активностями игроков рынка и показателями успешности их бизнеса. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126916983',
#    'premium': False,
#    'name': 'Аналитик больших данных (Big Data Analyst)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '72', 'name': 'Пермь', 'url': 'https://api.hh.ru/areas/72'},
#    'salary': {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'salary_range': {'from': 150000,
#     'to': None,
#     'currency': 'RUR',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': None},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Пермь',
#     'street': 'улица Спешилова',
#     'building': '96А',
#     'lat': 58.029031,
#     'lng': 56.217918,
#     'description': None,
#     'raw': 'Пермь, улица Спешилова, 96А',
#     'metro': None,
#     'metro_stations': [],
#     'id': '809184'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-24T14:45:41+0300',
#    'created_at': '2025-10-24T14:45:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126916983',
#    'show_logo_in_search': None,
#    'show_contacts': True,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126916983?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126916983',
#    'relations': [],
#    'employer': {'id': '2530296',
#     'name': 'Корпорация ПСС',
#     'url': 'https://api.hh.ru/employers/2530296',
#     'alternate_url': 'https://hh.ru/employer/2530296',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1328518.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/6934094.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/6934095.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2530296',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Имеют высшее образование в области Data Science, прикладной математики, статистики, информатики или смежной области. Имеют опыт работы с данными от...',
#     'responsibility': 'Оборудование для электрохимзащиты | ЭХЗ — катодная и протекторная антикоррозийная защита. Зарядные станции для электромобилей — надёжные решения для дома и бизнеса. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126075229',
#    'premium': False,
#    'name': 'Data analyst / Аналитик данных',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Санкт-Петербург',
#     'street': 'площадь Конституции',
#     'building': '3к2',
#     'lat': 59.850459,
#     'lng': 30.304738,
#     'description': None,
#     'raw': 'Санкт-Петербург, площадь Конституции, 3к2',
#     'metro': {'station_name': 'Московская',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.224',
#      'line_id': '15',
#      'lat': 59.848873,
#      'lng': 30.321483},
#     'metro_stations': [{'station_name': 'Московская',
#       'line_name': 'Московско-Петроградская',
#       'station_id': '15.224',
#       'line_id': '15',
#       'lat': 59.848873,
#       'lng': 30.321483}],
#     'id': '7101853'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-11-01T16:22:26+0300',
#    'created_at': '2025-11-01T16:22:26+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126075229',
#    'branding': {'type': 'CONSTRUCTOR', 'tariff': 'BASIC'},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126075229?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126075229',
#    'relations': [],
#    'employer': {'id': '4137632',
#     'name': 'Колл Солюшенс',
#     'url': 'https://api.hh.ru/employers/4137632',
#     'alternate_url': 'https://hh.ru/employer/4137632',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/950471.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/4242420.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/4242421.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4137632',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное владение инструментами анализа данных, такими как: MS Excel, SQL для обработки и анализа больших объемов данных. Практический опыт работы...',
#     'responsibility': 'Изучать поведение пользователей, заниматься поиском проблем и точек роста бизнеса. Искать причины роста и падения метрик. Оценивать риски, влияния и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '10', 'name': 'Аналитик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '127019693',
#    'premium': False,
#    'name': 'Стажер/Дата Аналитик в Скоринг [Big Data, МТС Веб Сервисы]',
#    'department': {'id': 'mts-3776-inIT', 'name': '"МТС", Работа в IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'проспект Андропова',
#     'building': '18к9',
#     'lat': 55.691734,
#     'lng': 37.660557,
#     'description': None,
#     'raw': 'Москва, проспект Андропова, 18к9',
#     'metro': {'station_name': 'ЗИЛ',
#      'line_name': 'МЦК',
#      'station_id': '95.531',
#      'line_id': '95',
#      'lat': 55.698333,
#      'lng': 37.648333},
#     'metro_stations': [{'station_name': 'ЗИЛ',
#       'line_name': 'МЦК',
#       'station_id': '95.531',
#       'line_id': '95',
#       'lat': 55.698333,
#       'lng': 37.648333},
#      {'station_name': 'ЗИЛ',
#       'line_name': 'Троицкая',
#       'station_id': '137.964',
#       'line_id': '137',
#       'lat': 55.697915,
#       'lng': 37.647565},
#      {'station_name': 'Коломенская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.53',
#       'line_id': '2',
#       'lat': 55.677423,
#       'lng': 37.663719},
#      {'station_name': 'Технопарк',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.512',
#       'line_id': '2',
#       'lat': 55.695,
#       'lng': 37.664167}],
#     'id': '19571148'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-27T17:03:33+0300',
#    'created_at': '2025-10-27T17:03:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127019693',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/127019693?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/127019693',
#    'relations': [],
#    'employer': {'id': '3776',
#     'name': 'МТС',
#     'url': 'https://api.hh.ru/employers/3776',
#     'alternate_url': 'https://hh.ru/employer/3776',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1389236.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7176731.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7176732.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3776',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Знание Python. Хороший уверенный SQL (оконные функции, работа с планом запроса). Понимание теории вероятности и математической статистики. Умение оценивать распределения...',
#     'responsibility': 'Автоматизировать процесс ретро-скоринга. Исследовать данные, создавать прототипы фичей и витрин. Настраивать мониторинг прогнозных моделей (в т.ч. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '10', 'name': 'Аналитик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': True,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '127060619',
#    'premium': False,
#    'name': 'Junior Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '90', 'name': 'Томск', 'url': 'https://api.hh.ru/areas/90'},
#    'salary': {'from': 111000, 'to': 167000, 'currency': 'RUR', 'gross': False},
#    'salary_range': {'from': 111000,
#     'to': 167000,
#     'currency': 'RUR',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Томск',
#     'street': 'микрорайон Черемошники, Нижне-Луговая улица',
#     'building': '16',
#     'lat': 56.51593,
#     'lng': 84.925065,
#     'description': None,
#     'raw': 'Томск, микрорайон Черемошники, Нижне-Луговая улица, 16',
#     'metro': None,
#     'metro_stations': [],
#     'id': '14870928'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-28T13:31:46+0300',
#    'created_at': '2025-10-28T13:31:46+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127060619',
#    'show_logo_in_search': None,
#    'show_contacts': True,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/127060619?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/127060619',
#    'relations': [],
#    'employer': {'id': '61750',
#     'name': 'Головное подразделение Сибагро',
#     'url': 'https://api.hh.ru/employers/61750',
#     'alternate_url': 'https://hh.ru/employer/61750',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/756594.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo/3467333.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/3467334.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=61750',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в среде Linux. Знание Python на продвинутом уровне. Опыт с фреймворками YOLO (например, YOLOv5/YOLOv8/YOLOv...',
#     'responsibility': 'Разметка и аннотация данных для задач машинного зрения: Проверка качества размеченных данных. Оценка эффективности моделей (метрики: точность, полнота, mAP и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126718438',
#    'premium': False,
#    'name': 'Data Scientist (Junior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'salary_range': {'from': None,
#     'to': 100000,
#     'currency': 'RUR',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': None},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': None,
#     'street': None,
#     'building': None,
#     'lat': 55.74146507524133,
#     'lng': 37.63113245701637,
#     'description': None,
#     'raw': 'Москва, Озерковский переулок, 12.',
#     'metro': None,
#     'metro_stations': [],
#     'id': '335836'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-11-01T11:21:52+0300',
#    'created_at': '2025-11-01T11:21:52+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126718438',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126718438?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126718438',
#    'relations': [],
#    'employer': {'id': '1056818',
#     'name': 'BND LLC',
#     'url': 'https://api.hh.ru/employers/1056818',
#     'alternate_url': 'https://hh.ru/employer/1056818',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/5736810.jpg',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/5736812.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/5736813.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1056818',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (математическое, техническое). Возможность работать полную рабочую неделю. Знание современных архитектур нейросетей. Понимание как устроены классические алгоритмы машинного обучения...',
#     'responsibility': 'Собирать и готовить данные для использования в ML-моделях. Разработка и поддержка микросервисов на Python, основанных на моделях компьютерного зрения...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126826034',
#    'premium': False,
#    'name': 'BI-аналитик (Data Analyst) в финасовый отдел (формат работы - только офис)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Багрицкого',
#     'building': '18',
#     'lat': 55.718907,
#     'lng': 37.43499,
#     'description': None,
#     'raw': 'Москва, улица Багрицкого, 18',
#     'metro': {'station_name': 'Кунцевская',
#      'line_name': 'Арбатско-Покровская',
#      'station_id': '3.69',
#      'line_id': '3',
#      'lat': 55.730673,
#      'lng': 37.446522},
#     'metro_stations': [{'station_name': 'Кунцевская',
#       'line_name': 'Арбатско-Покровская',
#       'station_id': '3.69',
#       'line_id': '3',
#       'lat': 55.730673,
#       'lng': 37.446522},
#      {'station_name': 'Кунцевская',
#       'line_name': 'Филевская',
#       'station_id': '4.471',
#       'line_id': '4',
#       'lat': 55.730815,
#       'lng': 37.446754},
#      {'station_name': 'Кунцевская',
#       'line_name': 'Большая кольцевая линия',
#       'station_id': '97.810',
#       'line_id': '97',
#       'lat': 55.730278,
#       'lng': 37.445833},
#      {'station_name': 'Кунцевская',
#       'line_name': 'МЦД-1',
#       'station_id': '131.704',
#       'line_id': '131',
#       'lat': 55.730554,
#       'lng': 37.445591}],
#     'id': '13793508'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-22T14:40:42+0300',
#    'created_at': '2025-10-22T14:40:42+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126826034',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126826034?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126826034',
#    'relations': [],
#    'employer': {'id': '4413765',
#     'name': 'AMCOR',
#     'url': 'https://api.hh.ru/employers/4413765',
#     'alternate_url': 'https://hh.ru/employer/4413765',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1397861.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7211215.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7211216.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4413765',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с BI-инструментами (Power BI - будет преимуществом, Tableau или аналогичными) от 3,5-4 лет и выше. ',
#     'responsibility': 'Предприятие, построенное «с нуля». Поэтапное освоение выпуска частей газотурбинных установок. Передовые технологии, новейшие запатентованные разработки. Собственный инженерно-конструкторский центр. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126979987',
#    'premium': False,
#    'name': 'Аналитик данных / Data analyst',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-27T12:05:38+0300',
#    'created_at': '2025-10-27T12:05:38+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126979987',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126979987?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126979987',
#    'relations': [],
#    'employer': {'id': '9757724',
#     'name': 'HuntIT',
#     'url': 'https://api.hh.ru/employers/9757724',
#     'alternate_url': 'https://hh.ru/employer/9757724',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1084973.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/5960521.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/5960522.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9757724',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Отличное знание SQL (мы используем ClickHouse и MySQL). Отличное знание Python (Pandas, Numpy, SciPy, Plotly). Знание статистики (описательная статистика, корреляционный...',
#     'responsibility': 'Обработка и анализ больших массивов данных. Построение дашбордов в Tableau, подготовка витрин для дашбордов. Полный флоу по проведению АБ-тестов...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#     {'id': 'REMOTE', 'name': 'Удалённо'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126315420',
#    'premium': False,
#    'name': 'Data Analyst',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Филипповский переулок',
#     'building': '8с1',
#     'lat': 55.748579,
#     'lng': 37.598555,
#     'description': None,
#     'raw': 'Москва, Филипповский переулок, 8с1',
#     'metro': None,
#     'metro_stations': [],
#     'id': '4646808'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-08T15:45:13+0300',
#    'created_at': '2025-10-08T15:45:13+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126315420',
#    'branding': {'type': 'CONSTRUCTOR', 'tariff': 'BASIC'},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126315420?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126315420',
#    'relations': [],
#    'employer': {'id': '2063837',
#     'name': 'Robusta',
#     'url': 'https://api.hh.ru/employers/2063837',
#     'alternate_url': 'https://hh.ru/employer/2063837',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1013563.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/5675020.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/5675021.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2063837',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт оценки трафика. Создание дашбордов в BI (желательно Tableau). Разработка аналитических моделей. Внимательность к данным и их точности. ',
#     'responsibility': 'Оценка качества трафика — анализировать и оценивать источники и параметры трафика для определения их эффективности и качества. Расчет оптимальных комиссий по...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
# ...
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126829038',
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126829038?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126829038',
#    'relations': [],
#    'employer': {'id': '5951038',
#     'name': 'ГКУ МО Центр Внедрения Изменений Министерства Здравоохранения Московской Области',
#     'url': 'https://api.hh.ru/employers/5951038',
#     'alternate_url': 'https://hh.ru/employer/5951038',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5951038',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Оконченное высшее образование по направлениям: Медицина и смежные области, проектный менеджмент, IT. Продвинутый уровень владения MS Excel (сводные таблицы, ВПР...',
#     'responsibility': 'Анализировать медицинские данные и искать первопричины массива зафиксированных инцидентов (выявление повторяющихся проблемных мест, причин сбоев и метрик эффективности). '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '10', 'name': 'Аналитик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '120549449',
#    'premium': False,
#    'name': 'Data analyst (Сервисы роботизации)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-30T16:14:55+0300',
#    'created_at': '2025-10-30T16:14:55+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=120549449',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/120549449?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/120549449',
#    'relations': [],
#    'employer': {'id': '87021',
#     'name': 'WILDBERRIES',
#     'url': 'https://api.hh.ru/employers/87021',
#     'alternate_url': 'https://hh.ru/employer/87021',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1395401.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7201387.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7201388.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=87021',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Имеете опыт работы аналитиком данных от 3 лет. Уверенно владеете SQL (ClickHouse) - подзапросы, оконные функции. Есть опыт работы с A...',
#     'responsibility': 'Искать закономерности в результатах проведённых исследований. Внедрять бизнес-метрики, которые помогают оценивать различные виды деятельности компаний. Использовать диагностическую аналитику для...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '148', 'name': 'Системный аналитик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126757294',
#    'premium': False,
#    'name': 'Data Scientist (Middle)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '22',
#     'name': 'Владивосток',
#     'url': 'https://api.hh.ru/areas/22'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Владивосток',
#     'street': 'Русская улица',
#     'building': None,
#     'lat': 43.169233,
#     'lng': 131.923268,
#     'description': None,
#     'raw': 'Владивосток, Русская улица',
#     'metro': None,
#     'metro_stations': [],
#     'id': '2489209'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-21T08:20:12+0300',
#    'created_at': '2025-10-21T08:20:12+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126757294',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126757294?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126757294',
#    'relations': [],
#    'employer': {'id': '823819',
#     'name': 'VL.RU',
#     'url': 'https://api.hh.ru/employers/823819',
#     'alternate_url': 'https://hh.ru/employer/823819',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1437251.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7368636.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7368637.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=823819',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Техническое образование. Опыт в области анализа данных и ML от 2 лет. Опыт работы с текстовыми моделями. Знание основ машинного...',
#     'responsibility': 'Подготовкой математического ядра для сервисов, связанных с поиском на Фарпосте. Помогать улучшать инфраструктуру и внедрять современные инженерные практики для наших...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '10', 'name': 'Аналитик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126775020',
#    'premium': False,
#    'name': 'Data аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-11-02T12:38:26+0300',
#    'created_at': '2025-11-02T12:38:26+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126775020',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126775020?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126775020',
#    'relations': [],
#    'employer': {'id': '4614421',
#     'name': 'RedLab',
#     'url': 'https://api.hh.ru/employers/4614421',
#     'alternate_url': 'https://hh.ru/employer/4614421',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1404568.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7237940.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7237941.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4614421',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с источниками данных, их обследование. Опыт проектирования витрин, необходимых для бизнеса. Сбор требований (БТ, ФТ, НФТ). ',
#     'responsibility': 'Проведение исследования (discovery) и, в частности, исследования по данным (data discovery). Подготовка артефактов и фиксация скоупа по результатам исследования. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '126925036',
#    'premium': False,
#    'name': 'Аналитик Data & AI Strategy',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '43', 'name': 'Калуга', 'url': 'https://api.hh.ru/areas/43'},
#    'salary': {'from': 280000, 'to': 360000, 'currency': 'RUR', 'gross': False},
#    'salary_range': {'from': 280000,
#     'to': 360000,
#     'currency': 'RUR',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': None},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Калуга',
#     'street': 'Параллельная улица',
#     'building': '11с18',
#     'lat': 54.559125,
#     'lng': 36.27168,
#     'description': None,
#     'raw': 'Калуга, Параллельная улица, 11с18',
#     'metro': None,
#     'metro_stations': [],
#     'id': '20201445'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-24T17:52:58+0300',
#    'created_at': '2025-10-24T17:52:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126925036',
#    'show_logo_in_search': None,
#    'show_contacts': True,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/126925036?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/126925036',
#    'relations': [],
#    'employer': {'id': '11537591',
#     'name': 'Jobers',
#     'url': 'https://api.hh.ru/employers/11537591',
#     'alternate_url': 'https://hh.ru/employer/11537591',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1347247.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo/7008930.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo/7008931.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11537591',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее техническое образование. Знание основ и ведущих мировых методологий (DAMA, DCAM и др.). Понимание базовых принципов построения архитектуры данных и...',
#     'responsibility': 'Выявление и документирование бизнес-потребностей в области стратегий данных и ИИ. Проведение аудита текущего состояния функций данных и аналитики с...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '125342770',
#    'premium': False,
#    'name': 'Аналитик данных/Data Analyst',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-10-15T14:06:08+0300',
#    'created_at': '2025-10-15T14:06:08+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=125342770',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/125342770?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/125342770',
#    'relations': [],
#    'employer': {'id': '87021',
#     'name': 'WILDBERRIES',
#     'url': 'https://api.hh.ru/employers/87021',
#     'alternate_url': 'https://hh.ru/employer/87021',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1395401.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7201387.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7201388.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=87021',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт в аналитике данных от 2 лет (работа с Gitlab / Airflow). Глубокое знание SQL и опыт работы с большими данными. ',
#     'responsibility': 'Разработка и развитие аналитических витрин: Вы будете с нуля проектировать, реализовывать и поддерживать витрины данных для глубокого анализа и отчётности. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '156',
#      'name': 'BI-аналитик, аналитик данных'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None}],
#  'found': 398,
#  'pages': 4,
#  'page': 0,
#  'per_page': 100,
#  'clusters': None,
#  'arguments': None,
#  'fixes': None,
#  'suggests': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?area=113&enable_snippets=true&items_on_page=100&search_field=name&text=name%3A%28data+analyst%29+OR+name%3A%28data+scientist%29'}

# %% [markdown]
# В списке вакансий есть только "верхнеуровневые данные". Чтобы получить "скилы", нужно "дергать" каждую вакансию по отдельности:

# %%
requests.get('https://api.hh.ru/vacancies/126905966').json()
# Out:
# {'id': '126905966',
#  'premium': False,
#  'billing_type': {'id': 'standard_plus', 'name': 'Стандарт плюс'},
#  'relations': [],
#  'name': 'Data Scientist (junior)',
#  'insider_interview': None,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': None,
#  'salary_range': None,
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Москва',
#   'street': 'проспект Лихачёва',
#   'building': '15',
#   'lat': 55.699872,
#   'lng': 37.644261,
#   'description': None,
#   'raw': 'Москва, проспект Лихачёва, 15',
#   'metro': {'station_name': 'Автозаводская',
#    'line_name': 'Замоскворецкая',
#    'station_id': '2.2',
#    'line_id': '2',
#    'lat': 55.706634,
#    'lng': 37.657008},
#   'metro_stations': [{'station_name': 'Автозаводская',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.2',
#     'line_id': '2',
#     'lat': 55.706634,
#     'lng': 37.657008},
#    {'station_name': 'ЗИЛ',
#     'line_name': 'Троицкая',
#     'station_id': '137.964',
#     'line_id': '137',
#     'lat': 55.697915,
#     'lng': 37.647565}]},
#  'allow_messages': True,
#  'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'department': {'id': '8582-8582-lmteh', 'name': 'ИТ'},
#  'show_contacts': False,
#  'contacts': None,
#  'description': '<strong>Обязанности:</strong> <ul> <li> <p>Работа с большими данными, EDA, построение выборок, аналитика, умение строить выводы и формулировать гипотезы, исходя из проблематики (в т.ч. поиск проблематики, если необходимо)</p> </li> <li> <p>Самостоятельное моделирование и интерпретация данных, разработка алгоритмов и статистических моделей, проведение и анализ результатов А/Б тестов</p> </li> <li> <p>Формализация требований к сбору обучающей выборки</p> </li> <li> <p>Генерация и проверка гипотез</p> </li> <li> <p>Проведение исследований алгоритмов машинного обучения</p> </li> <li> <p>Дизайн, разработка и тюнинг моделей машинного обучения</p> </li> <li> <p>Построение и оптимизация пайплайнов от признаков до обучения моделей</p> </li> <li> <p>Продуктивизация ML-решений</p> </li> <li> <p>Проведение аналитических исследований и R&amp;D на больших данных с применением ML</p> </li> <li> <p>Поддержка работоспособности решений, контроль качества получаемых данных</p> </li> <li> <p>Представление результатов и автоматизация отслеживания метрик продукта</p> </li> <li> <p>Документирование своей работы в GitHub, Яндекс Вики, Яндекс Трекер</p> </li> </ul> <p> </p> <p><strong>Требования:</strong></p> <ul> <li> <p>Высшее техническое образование</p> </li> <li> <p>Опыт работы в аналитике/ data science от 1 года</p> </li> <li> <p>Знание Теории вероятности, Мат. анализа и линейной алгебры, достаточного для чтения научных статей и проведения экспериментов</p> </li> <li> <p>Умение проверять статистические гипотезы, знание основных критериев</p> </li> <li> <p>Знание и понимание основных метрик и принципов оценки качества моделей и получаемого с их помощью результата, способов валидации моделей</p> </li> <li> <p>Инструменты</p> </li> <li> <p>Уверенное знание python (+ классический набор библиотек для анализа данных/ машинного обучения: scikit-learn, numpy, pandas, plotly/ matplotlib/ seaborn</p> </li> <li> <p>Опыт обучения моделей градиентного бустинга, использования одной из библиотек (Catboost, LightGBM, XGBoost)</p> </li> <li> <p>Знание SQL, опыт работы с реляционными СУБД на уровне пользователя</p> </li> <li> <p>Умение работать с Git</p> </li> <li> <p>Навыки</p> </li> <li> <p>Опыт анализа данных на предмет применимости к решению задачи (EDA)</p> </li> <li> <p>Опыт поиска, визуализации и интерпретации полезных сигналов и аномалий в данных;</p> </li> <li> <p>Способность структурировать знания, формулировать и проверять гипотезы;</p> </li> <li> <p>Аналитический склад ума, привычка видеть физический смысл за цифрами и данными;</p> </li> <li> <p>Умение ясно и чётко выражать мысли устно, письменно и графически, понимать язык бизнеса и разработки;</p> </li> <li> <p>Способность к командной работе, нацеленность на результат.</p> </li> </ul> <p> </p> <p><strong>Условия:</strong></p> <ul> <li> <p>Работа в компании с развитой инженерной культурой;</p> </li> <li> <p>Гибкая система премирования;</p> </li> <li> <p>Расширенный социальный пакет: ДМС со стоматологией с первого месяца работы, психолог и страхование жизни, компенсация питания и оплата мобильной связи;</p> </li> <li> <p>Возможности профессионального роста, программы развития для сотрудников;</p> </li> <li> <p>Корпоративное обучение и доступ к базе знаний;</p> </li> <li> <p>Внутренние профессиональные сообщества и мероприятия;</p> </li> <li> <p>Автономность работы, возможность менять правила, ошибаться и создавать новое;</p> </li> <li> <p>Гибридный формат работы;</p> </li> <li> <p>Современный офис в 2 минутах ходьбы от МЦК ЗИЛ.</p> </li> </ul> <p>С каждым годом на выбор сотрудника становится доступно больше дополнительных опций. Например, частичная компенсация путешествий, затрат на обучение, спортивных занятий.</p> <p> </p>',
#  'branded_description': None,
#  'vacancy_constructor_template': None,
#  'key_skills': [{'name': 'Python'},
#   {'name': 'SQL'},
#   {'name': 'Математическая статистика'},
#   {'name': 'CatBoost'},
#   {'name': 'XGBoost'}],
#  'auto_response': {'accept_auto_response': True},
#  'accept_handicapped': False,
#  'accept_kids': False,
#  'age_restriction': None,
#  'archived': False,
#  'response_url': None,
#  'specializations': [],
#  'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#  'code': None,
#  'hidden': False,
#  'quick_responses_allowed': False,
#  'driver_license_types': [],
#  'accept_incomplete_resumes': False,
#  'employer': {'id': '8582',
#   'name': 'Лемана ПРО',
#   'url': 'https://api.hh.ru/employers/8582',
#   'alternate_url': 'https://hh.ru/employer/8582',
#   'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1423644.png',
#    '90': 'https://img.hhcdn.ru/employer-logo/7314225.png',
#    '240': 'https://img.hhcdn.ru/employer-logo/7314226.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=8582',
#   'country_id': 1,
#   'accredited_it_employer': False,
#   'trusted': True},
#  'published_at': '2025-11-02T11:19:08+0300',
#  'created_at': '2025-11-02T11:19:08+0300',
#  'initial_created_at': '2025-10-24T11:19:08+0300',
#  'negotiations_url': None,
#  'suitable_resumes_url': None,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126905966',
#  'has_test': False,
#  'test': None,
#  'alternate_url': 'https://hh.ru/vacancy/126905966',
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'languages': [],
#  'approved': True,
#  'employment_form': {'id': 'FULL', 'name': 'Полная'},
#  'fly_in_fly_out_duration': [],
#  'internship': False,
#  'night_shifts': False,
#  'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#  'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#  'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#  'show_logo_in_search': None,
#  'closed_for_applicants': False}

# %% [markdown]
# **Итого, подход к сбору данных:**
# * Собираем данные о вакансиях, соответствующих заданному условию (по дате, региону, наименованию)
# * Для каждой полученной вакансии "забираем" данные о ключевых навыках и описание вакансии (описание - на случай, если навыки не указаны, тогда их можно будет извлечь с помощью LLM).

# %% [markdown]
# # Теперь проработаем сохранение необходимых данныx в pandas DataFrame

# %%
# сохраним словарь со списком вакансий:
vac_list = requests.get(BASE_URL, params=DEFAULT_PARAMS).json()['items']

# %% [markdown]
# Посмотрим несколько вакансий

# %%
vac_list[2]
# Out:
# {'id': '127192646',
#  'premium': False,
#  'name': 'Младший аналитик данных/Junior Data Analyst',
#  'department': None,
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': None,
#  'salary_range': None,
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Москва',
#   'street': 'улица Двинцев',
#   'building': '12к1Б',
#   'lat': 55.796764,
#   'lng': 37.599013,
#   'description': None,
#   'raw': 'Москва, улица Двинцев, 12к1Б',
#   'metro': {'station_name': 'Марьина Роща',
#    'line_name': 'Люблинско-Дмитровская',
#    'station_id': '10.185',
#    'line_id': '10',
#    'lat': 55.793723,
#    'lng': 37.61618},
#   'metro_stations': [{'station_name': 'Марьина Роща',
#     'line_name': 'Люблинско-Дмитровская',
#     'station_id': '10.185',
#     'line_id': '10',
#     'lat': 55.793723,
#     'lng': 37.61618},
#    {'station_name': 'Савёловская',
#     'line_name': 'Серпуховско-Тимирязевская',
#     'station_id': '9.128',
#     'line_id': '9',
#     'lat': 55.794054,
#     'lng': 37.587163},
#    {'station_name': 'Савёловская',
#     'line_name': 'Большая кольцевая линия',
#     'station_id': '97.685',
#     'line_id': '97',
#     'lat': 55.794054,
#     'lng': 37.587163}],
#   'id': '19253248'},
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2025-10-31T17:40:06+0300',
#  'created_at': '2025-10-31T17:40:06+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127192646',
#  'branding': {'type': 'MAKEUP', 'tariff': None},
#  'show_logo_in_search': True,
#  'show_contacts': False,
#  'insider_interview': {'id': '33742',
#   'url': 'https://hh.ru/interview/33742?employerId=2739341'},
#  'url': 'https://api.hh.ru/vacancies/127192646?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/127192646',
#  'relations': [],
#  'employer': {'id': '2739341',
#   'name': 'Mediascope',
#   'url': 'https://api.hh.ru/employers/2739341',
#   'alternate_url': 'https://hh.ru/employer/2739341',
#   'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/966623.png',
#    '90': 'https://img.hhcdn.ru/employer-logo/5484932.png',
#    '240': 'https://img.hhcdn.ru/employer-logo/5484933.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2739341',
#   'country_id': 1,
#   'accredited_it_employer': True,
#   'trusted': True},
#  'snippet': {'requirement': 'Высшее профильное образование. Опыт чтения документации DWH. Уверенное владение SQL или Python. Умение использовать продвинутые функции Excel. Опыт работы с...',
#   'responsibility': 'Лаб тесты/тесты обновлений инструментов, приложений. Делаем эксперименты и анализ различных моделей совместно с командами RnD и Data Science, строим...'},
#  'contacts': None,
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'fly_in_fly_out_duration': [],
#  'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#   {'id': 'HYBRID', 'name': 'Гибрид'}],
#  'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#  'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#  'night_shifts': False,
#  'professional_roles': [{'id': '156', 'name': 'BI-аналитик, аналитик данных'}],
#  'accept_incomplete_resumes': False,
#  'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'employment_form': {'id': 'FULL', 'name': 'Полная'},
#  'internship': False,
#  'adv_response_url': None,
#  'is_adv_vacancy': False,
#  'adv_context': None}

# %%
vac_list[5]
# Out:
# {'id': '126209623',
#  'premium': False,
#  'name': 'Стажер, Data Analyst / Data Scientist',
#  'department': {'id': '201-201-itserv', 'name': 'Kept, ИТ-сервисы'},
#  'has_test': True,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': None,
#  'salary_range': None,
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Москва',
#   'street': 'Ленинградский проспект',
#   'building': '34А',
#   'lat': 55.78531580767879,
#   'lng': 37.567994114085565,
#   'description': None,
#   'raw': 'Москва, Ленинградский проспект, 34А',
#   'metro': {'station_name': 'Динамо',
#    'line_name': 'Замоскворецкая',
#    'station_id': '2.34',
#    'line_id': '2',
#    'lat': 55.789704,
#    'lng': 37.558212},
#   'metro_stations': [{'station_name': 'Динамо',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.34',
#     'line_id': '2',
#     'lat': 55.789704,
#     'lng': 37.558212},
#    {'station_name': 'Петровский парк',
#     'line_name': 'Большая кольцевая линия',
#     'station_id': '97.599',
#     'line_id': '97',
#     'lat': 55.79233,
#     'lng': 37.55952}],
#   'id': '16628589'},
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2025-10-06T18:43:16+0300',
#  'created_at': '2025-10-06T18:43:16+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=126209623',
#  'branding': {'type': 'MAKEUP', 'tariff': None},
#  'show_logo_in_search': True,
#  'show_contacts': False,
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/126209623?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/126209623',
#  'relations': [],
#  'employer': {'id': '201',
#   'name': 'Kept (Кэпт)',
#   'url': 'https://api.hh.ru/employers/201',
#   'alternate_url': 'https://hh.ru/employer/201',
#   'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1077254.png',
#    '90': 'https://img.hhcdn.ru/employer-logo/5929645.png',
#    '240': 'https://img.hhcdn.ru/employer-logo/5929646.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=201',
#   'country_id': 1,
#   'accredited_it_employer': False,
#   'trusted': True},
#  'snippet': {'requirement': 'Высшее образование или в том числе студент старших курсов в области математики, информатики в бизнесе и аналогичные. Хороший уровень Python...',
#   'responsibility': 'Применение продвинутых ИТ подходов на реальных проектах консалтинга. Разработка инструментов работы с данными, повышающими эффективность проектов. Внедрение новых подходов по...'},
#  'contacts': None,
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'fly_in_fly_out_duration': [],
#  'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#  'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#  'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#  'night_shifts': False,
#  'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#  'accept_incomplete_resumes': False,
#  'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'employment_form': {'id': 'FULL', 'name': 'Полная'},
#  'internship': True,
#  'adv_response_url': None,
#  'is_adv_vacancy': False,
#  'adv_context': None}

# %% [markdown]
# На первый взгляд интерес представляют поля:
# 1. `id`
# 2. `name`
# 3. `area['name']`
# 4. `experience['name']`
#
# Детальные данные по скилам и требованиям будем получать уже непосредственно из описаний вакансий

# %%
vac_base = pd.DataFrame(columns=['id','name','area','experience'])

# %%
for vac in vac_list:
    vac_base.loc[len(vac_base)] = [
        vac.get('id'),
        vac.get('name'),
        (vac.get('area') or {}).get('name'),
        (vac.get('experience') or {}).get('name'),
    ]

# %%
vac_base.sample(5)
# Out:
#            id                            name    area          experience
# 44  127138420          Data аналитик (AdTech)  Москва       От 3 до 6 лет
# 45  127181192                  Data Scientist  Москва       От 3 до 6 лет
# 70  126776801                  Data Scientist  Москва  От 1 года до 3 лет
# 54  126920458  Аналитик данных / Data Analyst  Москва  От 1 года до 3 лет
# 80  126231402  Data Scientist, NLP, Ozon Банк  Москва  От 1 года до 3 лет

# %% [markdown]
# Собрали список. Следующий шаг - по id вакансии добавить в таблицу навыки и описание (поля `key_skills` и `description`)

# %%
i=0
for id in vac_base['id']:
    resp = BASE_URL+'/'+str(id) # Создаем ссылку на вакансию
    vac = requests.get(resp).json()
    time.sleep(0.5) # Задержка обращения по API
    print(i,end='. ')
    for el in vac['key_skills']:
        print(el['name'],end=', ')
    soup = BeautifulSoup(vac['description'], 'html.parser')
    print(soup.get_text())
    print()
    i+=1
    if i == 5:
        break
# Out:
# 0. Обязанности:  Моделирование клиентского поведения, прогнозирование оттока; Работа в Yandex DataSphere, создание и тренировка ML-моделей; Подготовка данных для моделей (ETL-процессы, очистка, фичи); Построение системы «цифрового двойника клиента».  Требования:  Уверенное владение Python, pandas, scikit-learn, MLflow; Опыт работы в DataSphere или аналогичных средах; Знание SQL и базовых принципов ETL; Понимание клиентской аналитики, NPS, retention.  Условия:  Интересные задачи и проекты; Оформление по ТК РФ; Официальная заработная плата (уровень оплаты труда, обсуждается с успешным кандидатом на собеседовании); График работы 5/2 пн-чт с 09.30 до 18.15, пятница с 09.30 до 17.00.
#
# 1. Python, SQL, Базы данных, Анализ данных, Ищем специалиста, готового влиться в команду профессионалов в один из крупнейших банков страны. Сегодня мы в поиске Аналитика данных. Основные обязанности:  Работа в функциональной команде, нацеленной на развитие продаж Работа с базами данных с целью оцифровки и разработки моделей прогнозирования Проведение исследований Сопровождение A/B тестов Разработка регламентной отчётности и дашбордов Анализ и поиск решений повышения эффективности продаж  Требования:  Опыт работы аналитиком данных от 9 месяцев и выше Развитое критическое и системное мышление, понимание основ теории вероятностей и математической статистики Знание Python (базовый уровень), SQL на уровне middle Опыт работы с DWH Знания Apache Superset будет являться преимуществом  Что мы предлагаем:    Заработная плата обсуждаются на финальном собеседовании с руководителем Бонус по итогам года за отличную работу Удалённый формат работы: понедельник–пятница, 10:00–19:00 (возможен 1 офисный день в неделю) Оформление: по ТК РФ, стабильные выплаты Полис ДМС и страховка от несчастных случаев для сотрудника, льготные условия страхования для близких Специальные тарифы по картам и кредитам от банка Скидки и акции от партнёров компании Возможности профессионального и карьерного роста: обучение, курсы, наставничество и развитие личной эффективности  Уважаемые кандидаты! Просьба при отклике указывать свои ЗП ожидания и телеграмм для связи.
#
# 2. Python, SQL, Аналитическое мышление, Исследовательский анализ данных, Математическая статистика, Интерпретация данных, Регрессионный анализ, Mediascope – исследовательская компания, которая работает на стыке медиа и IТ. Мы анализируем аудиторию телевидения, интернета, радио и прессы, поставляем данные и создаем уникальные аналитические продукты, которыми пользуются российские медиа, рекламные агентства и компании-рекламодатели. Наша задача – создавать и поддерживать индустриальные стандарты работы с данными на рынке медиа и рекламы, а также развивать медиаисследования в России. О команде, в которой предстоит работать: Ключевой продукт нашей компании это данные и аналитика, построенная на них. Поэтому у нас построена огромная инфраструктура по сбору и обработке самых разнообразной и интересной информации о пользователях интернета (и не только). А еще много разнообразных задач, связанных с этими данными. У нас молодой, активный и крайне увлеченный коллектив из менеджеров и аналитиков. Наша команда реализации проектов находится на стыке 4 морей: клиентские менеджеры, разработка, производство и эксплуатация. Поэтому у нас много всего интересного:  Лаб тесты/тесты обновлений инструментов, приложений Делаем эксперименты и анализ различных моделей совместно с командами RnD и Data Science, строим прототипы Разбираем странные кейсы, ищем аномалии Проверяем доработки от команды разработчиков Формируем ТЗ для команды эксплуатации по контролю качества, разбираем вместе с ними инциденты и аллерты Готовим описания для внутреннего и внешнего использования  Чем предстоит заниматься:  Изучать большой объем данных с помощью инструментов BigData и искать в них зависимости, аномалии, ошибки Проводить анализ данных: сбор и загрузка данных, преобразование данных в удобный для исследования вид, проверка их качества и полноты, аналитические выводы Валидировать источники данных и их последующую обработку с точки зрения бизнес-смысла Сопровождать процесс разработки и внедрения проектов Участвовать в разборе инцидентов и исправлении ошибок Находить причины аномалий, ошибки в данных и курировать их исправление Документировать различную информацию (база знаний в Confluence)  Что для этого потребуется:  Высшее профильное образование Опыт чтения документации DWH Уверенное владение SQL или Python Умение использовать продвинутые функции Excel Опыт работы с Zeppelin, Spark, Jupyter Notebook, таблицами HDFS (как плюс) Базовые знания статистического анализа Опыт работы в аналитике данных от 1 года  Мы предоставим комфортные условия для работы:  Возможность выбирать формат работы – офис, гибрид Официальное оформление, гарантируем соблюдения трудового кодекса РФ Расширенная медицинская страховка (включая стоматологию) Используем современный стек технологий и открыты к внедрению новых инструментов Работа в аккредитованной IT -компании Мы умеем быстро подстраиваться под изменения, и у нас внутри гибкие процессы Наши заказчики – крупные компании на российском медиарынке, у нас разные проекты от значимых до очень значимых  Наши преимущества:  Выделенный наставник с первых дней работы: мы понимаем, что новая компания - всегда стресс, поэтому у нас новичкам помогают старшие коллеги Внутренние коммьюнити: 2 трека внутренних митапов для аналитиков и инженеров; возможность выступать как спикер или приходить на выступления других коллег в качестве слушателя Карьерный рост: при хороших результатах работы вы быстро двигаетесь по карьерному треку Уникальная корпоративная культура, ориентированная на людей. Для нас важен каждый коллега, мы всегда открыты к диалогу и любым вопросам сотрудников
#
# 3. SQL, Python, Визуализация данных, MLflow,  Мы — не просто компания. Мы — драйвер изменений и лидирующий провайдер финансовых услуг и сервисов в России.   Залог успеха IDF Eurasia - команда высококлассных экспертов. Мы ценим работу каждого и поддерживаем обмен опытом между подразделениями. Тебя будут окружать эксперты, с которыми ты с уверенностью сможешь бросить вызов самым нестандартным задачам.   Стратегия, Исполнение и Команда — ценности, лежащие в основе нашей культуры.   Ищем Junior Data Scientist, который хочет расти под руководством опытных коллег и участвовать в полном цикле создания и внедрения ML-моделей, на проект Moneyman.    Чем предстоит заниматься:  Участвовать в полном цикле разработки и эксплуатации скоринговых и предиктивных моделей под руководством старших коллег: от сбора данных и анализа до запуска в промышленную эксплуатацию. Вести документацию по моделям и задачам. Заниматься ad-hoc аналитикой. Взаимодействовать с заказчиками. Совершенствовать процесс разработки моделей, наполнение feature store и ABT-витрин, дорабатывать общие фреймворки разработки. Использовать стек: ClickHouse SQL, Python (библиотеки: pandas, numpy, scikit-learn, catboost), Airflow, MLflow.    Наши ожидания:   Знание Python и ключевых библиотек (Pandas, Scikit-learn) для анализа данных и машинного обучения.   Опыт написания SQL-запросов для извлечения и обработки данных.   Понимание основ ML: знакомство с основными алгоритмами и подходами к построению предсказательных моделей.   Навыки визуализации данных: умение строить понятные графики (Matplotlib/Seaborn) и/или дашборды (Tableau/Power BI).   Аналитический склад ума и внимание к деталям, подкрепленные знанием основ статистики.   Обучаемость и желание развиваться под руководством старших коллег, готовность участвовать в полном цикле проектов.   Ответственность и аккуратность в работе с кодом и документацией.  Будет преимуществом наличие pet-проектов / участие в хакатонах.    Мы предлагаем:  Профессиональное развитие – участие в разных проектах холдинга, создание новых направлений, влияние на бизнес-процессы и свободу в принятии решений. Прокачку скиллов – решение нестандартных задач + карт-бланш на смелые идеи и возможность быстро видеть реальный результат. Карьерный рост – ты будешь понимать, что нужно сделать для перехода на другой уровень. Работу в динамике – каждый день новые вызовы, где рутина уступает место крутым кейсам. Команду мечты – эксперты без бюрократии, открытый диалог с топ-менеджментом, основателями и идейными вдохновителями бизнеса. Комфортный офис м. Парк Победы/Фили/Багратионовская в пешей доступности в гибридном формате или полностью удаленный формат. Стабильный уровень дохода (оклад + премии), размер заработной платы обсуждается по итогам собеседования. Более, чем привлекательный компенсационный пакет: программа ДМС, в которую входит стоматология и обслуживание в лучших клиниках города; корпоративное такси; 8 дополнительных дней к отпуску; обучение и участие в конференциях.
#
# 4. Привет! Мы команда разработчиков платформы Young&Junior, которая собирает вакансии со всех интернет-ресурсов. Сейчас нашим сайтом пользуется 30 000 человек ежемесячно, и мы активно растем, поэтому набираем сотрудников в отдел аналитики. На данный момент мы разработали агрегатор вакансий, который парcит вакансии по 6 направлениям. В ближайшие время планируем внедрять новые фичи:  -Добавить на сайт конструктор резюме -Интегрировать сайт с нашим тренажером собеседований -Расширить блок с IT мероприятиями и ИИ-инструментами для джунов Поэтому нам нужны активные, инициативные аналитики. Чем предстоит заниматься?   Собирать и обрабатывать данные из различных источников для последующего анализа   Создавать визуализации и дашборды для мониторинтра ключевых метрик продукта   Участвовать в анализе пользовательского поведения и ключевых сценариев (например, воронка от поиска вакансии до отклика)   Тесно взаимодействовать с командами продукта и разработки, помогая формировать требования к данным и проверяя их качество   Активно участвовать в планировании и обсуждении задач, предлагая идеи по улучшению методов анализа и метрик   Что мы предлагаем?  Влияние на продукт: твои решения сразу повлияют на тысячи пользователей. Полностью удалённая работа с гибким графиком. Обучение и рост.  Обязательные требования:   Базовые знания SQL для работы с данными   Навыки работы с Excel/Google Таблицами (сводные таблицы, основные функции)   Понимание основ статистики и анализа данных   Внимательность к деталям и умение работать с большими объемами информации   Способность работать в команде, воспринимать обратную связь и постоянно учиться   Будет плюсом:   Опыт работы с системами визуализации данных (Tableau, Power BI, DataLens и др.)   Базовые знания Python (pandas, numpy) для анализа данных   Знакомство с процессами гибкой разработки (Scrum/Kanban)   Понимание принципов веб-аналитики и метрик продукта   Наличие учебных проектов или кейсов по анализу данных   До встречи на собесе!

# %%
# Разобрались с "выдергиванием" навыков и описания вакансии, теперь соберем DataFrame
vac_details = [] # список для хранения
# i = 0
for id in vac_base['id']:
    # i+=1
    resp = BASE_URL+'/'+str(id)
    vac = requests.get(resp).json()
    time.sleep(1) # при задержке в 0.5 секунды сессия обрывалась, увеличил до одной секунды, на 100 вакансиях отработала

    # достаем навыки
    skills = ', '.join([el['name'] for el in vac.get('key_skills',[])])

    # чистим текст
    description = BeautifulSoup(vac.get('description', ''), 'html.parser').get_text().strip()

    # добавляем данные в список словарей
    vac_details.append({
        'id':id,
        'key_skills':skills,
        'description':description
    })
    # if i == 5:
    #     break
vac_df = pd.DataFrame(vac_details)
vac_df.sample(5)
# Out:
#            id                                         key_skills  \
# 91  127194992
# 61  126786396                       SQL, Power BI, Бизнес-анализ
# 69  125390186  Python, PyTorch, TensorFlow, Self-Supervised L...
# 54  126920458  Аналитическое мышление, Анализ данных, MS Exce...
# 12  126826034  SQL, MS SQL, Power BI, Визуализация данных, Фо...
#
#                                           description
# 91  Чем предстоит заниматься:   Анализ пользовател...
# 61  Finstar Financial Group – крупный международны...
# 69  Computer Vision. Разработка и оптимизация алго...
# 54  АНО "Диалог Регионы" – федеральная компания, у...
# 12  Компания AMCOR – отечественная инжиниринговая ...

# %%
# объединим полученные таблицы по id
vac_full = pd.merge(vac_base, vac_df, on='id', how='left')
vac_full.sample(5)
# Out:
#            id                                name    area          experience  \
# 62  124119703   Data scientist Geospatial Analyst  Москва  От 1 года до 3 лет
# 95  120549449  Data analyst (Сервисы роботизации)  Москва  От 1 года до 3 лет
# 14  126315420                        Data Analyst  Москва       От 3 до 6 лет
# 54  126920458      Аналитик данных / Data Analyst  Москва  От 1 года до 3 лет
# 89  127184837                      Data Scientist  Москва       От 3 до 6 лет
#
#                                            key_skills  \
# 62
# 95
# 14                         SQL, Python, Анализ данных
# 54  Аналитическое мышление, Анализ данных, MS Exce...
# 89
#
#                                           description
# 62  Обязанности:• Создание и непрерывное улучшение...
# 95  Объединённая компания Wildberries и Russ — это...
# 14  Robusta — международная IT компания, которая р...
# 54  АНО "Диалог Регионы" – федеральная компания, у...
# 89  Мы создаём продукт, который меняет то, как FMC...

# %% [markdown]
# Получилось:
# * Вытащить список вакансий по заданным параметрам
# * Для каждой вакансии получить поля "ключевые навыки" и "описание вакансии"
#
# Следующий шаг - написание функции для системного сбора данных о вакансиях

# %%
def vacancyParser(url=BASE_URL, params=None, pause=1.5, max_pages=None):
    base_params = (params or DEFAULT_PARAMS).copy()

    # первичный запрос: узнаём число страниц
    r = requests.get(url, params=base_params)
    r.raise_for_status()
    data = r.json()
    pages = data.get('pages', 0)

    if max_pages is not None:
        pages = min(pages, max_pages)

    # собираем базовую таблицу вакансий
    rows = []
    for page in tqdm(range(pages), total=pages, desc="Страницы"):
        page_params = base_params.copy()
        page_params['page'] = page

        resp = requests.get(url, params=page_params)
        resp.raise_for_status()
        items = resp.json().get('items', [])

        for vac in items:
            rows.append({
                'id': vac.get('id'),
                'name': vac.get('name'),
                'area': (vac.get('area') or {}).get('name'),
                'experience': (vac.get('experience') or {}).get('name'),
            })

        time.sleep(pause)

    vacancyBase = pd.DataFrame(rows, columns=['id','name','area','experience'])

    # собираем детали по каждой вакансии
    details = []
    for vid in tqdm(vacancyBase['id'], desc="Детали", total=len(vacancyBase)):
        resp = requests.get(f"{url}/{vid}")
        if resp.status_code != 200:
            continue
        vacancy = resp.json()
        time.sleep(pause)

        skills_list = ', '.join([el.get('name') for el in (vacancy.get('key_skills') or [])])

        # Чистим HTML в описании
        description = BeautifulSoup(
            vacancy.get('description', '') or '',
            'html.parser'
        ).get_text().strip()

        details.append({
            'id': vid,
            'key_skills': skills_list,
            'description': description
        })

    details_df = pd.DataFrame(details, columns=['id','key_skills','description'])

    # объединяем
    if not details_df.empty:
        vacancyBase = vacancyBase.merge(details_df, on='id', how='left')
    else:
        vacancyBase['key_skills'] = [[] for _ in range(len(vacancyBase))]
        vacancyBase['description'] = ""

    return vacancyBase

# %%
vb = vacancyParser()
vb.sample(5)
# Out:
# Страницы: 100%|██████████| 4/4 [00:08<00:00,  2.02s/it]
# Детали: 100%|██████████| 398/398 [12:07<00:00,  1.83s/it]
#             id                           name    area          experience  \
# 325  126795918        Data Scientist (Senior)  Москва       От 3 до 6 лет
# 174  124803044                 Data Scientist  Москва  От 1 года до 3 лет
# 225  126119482  Data Scientist Middle/Middle+  Москва  От 1 года до 3 лет
# 168  126314693  Data Scientist (Блок Финансы)  Москва  От 1 года до 3 лет
# 302  125969338                 Data Scientist  Москва  От 1 года до 3 лет
#
#     key_skills                                        description
# 325             «М.ТЕХ» - АККРЕДИТОВАННАЯ ИТ-КОМПАНИЯ В ГРУППЕ...
# 174             Группа компаний Протектор – ведущий поставщик ...
# 225             Обязанности:-Разрабатывать, внедрять и оптимиз...
# 168             Мы развиваем решения в области uplift-моделиро...
# 302             Вам предстоит:  Построение и обучение моделей ...

# %% [markdown]
# Собрали данные по 398 вакансиям направления `data analyst`, `data scientist`.
# Далее:
# * Сохраним датасет
# * Впоследствии будем получать только данные по новым вакансиям, которых нет в базе и пополнять нашу базу вакансий

# %%
def saveVacanciesToCsv(df, dirPath = RAW_DIR, prefix = 'Vacancies_on'):
    outDir = Path(dirPath)
    outDir.mkdir(parents=True, exist_ok=True)

    ts = dt.datetime.today().strftime('%Y%m%d')
    fname = outDir / f"{prefix}_{ts}.csv"

    df.to_csv(fname, index=False, encoding='utf-8-sig')

    print(f'Данные сохранены в CSV: {fname}')

# %%
saveVacanciesToCsv(df=vb) #Сохранили полученную базу вакансий в csv
# Out:
# Данные сохранены в CSV: ..\data\raw_data\Vacancies_on_20251104.csv

# %% [markdown]
# Сделаем следующие шаги:
# * Создадим отдельный файл с мастер-данными, содержащий все собранные данные
# * Создадим функцию новых данных, работающую след. образом:
#     * Берем список id из мастер-файла
#     * Получаем запросом список вакансий
#     * Только по вакансиям, отсутствующим в мастер файле парсим навыки и описание
#     * Создаем новый CSV файл
#     * Добавляем данные в мастер-файл.

# %%
# Сохраним собранные данные в мастер-файл

vb.to_csv(RAW_DIR / 'vacancies_master.csv', index=False, encoding='utf-8-sig')

# %%
# Проверяем наличие/создаем мастер-файл
def ensureMaster(master_path: Path = MASTER_PATH):
    master_path.parent.mkdir(parents=True, exist_ok=True)
    if not master_path.exists():
        pd.DataFrame(columns=MASTER_COLUMNS).to_csv(
            master_path, index=False, encoding="utf-8-sig"
        )
        print(f"Создан пустой мастер-файл: {master_path}")
    else:
        print(f"Мастер-файл найден: {master_path}")

# Получаем id имеющихся вакансий
def getMasterIds(master_path: Path = MASTER_PATH) -> set:
    ensureMaster(master_path)
    df = pd.read_csv(master_path, dtype=str)
    return set(df["id"].dropna().astype(str).tolist())

# %%
# Получаем список вакансий
def fetchVacansiesList(params = DEFAULT_PARAMS, max_pages = None, pause = 1.5):
    r = requests.get(BASE_URL, params=params)
    r.raise_for_status()
    data = r.json()
    pages_total = data.get('pages', 0)

    if max_pages is not None:
        pages_total = min(pages_total, max_pages)

    rows = []
    for page in tqdm(range(pages_total), desc="Поиск"):
        page_params = {**params, "page": page}
        resp = requests.get(BASE_URL, params=page_params)
        resp.raise_for_status()
        items = resp.json().get("items", [])
        for it in items:
            rows.append({
                "id": it.get("id"),
                "name": it.get("name"),
                "area": (it.get("area") or {}).get("name"),
                "experience": (it.get("experience") or {}).get("name"),
            })
        time.sleep(pause)

    return pd.DataFrame(rows, columns=["id","name","area","experience"])

# Оставляем те, которых нет в мастере
def filterNewIds(df_basic: pd.DataFrame, master_ids: set) -> pd.DataFrame:

    df_basic = df_basic.astype({"id": str})
    mask_new = ~df_basic["id"].isin(master_ids)
    return df_basic.loc[mask_new].drop_duplicates(subset=["id"])

# %%
master_ids = getMasterIds()

params = DEFAULT_PARAMS.copy()
params["page"] = 0

df_basic = fetchVacansiesList(params=params, max_pages=5)
df_new_basic = filterNewIds(df_basic, master_ids)

print(f"Найдено в поиске: {len(df_basic)}")
print(f"Новых (ещё не в мастере): {len(df_new_basic)}")
# Out:
# Мастер-файл найден: ..\data\raw_data\vacancies_master.csv
# Поиск: 100%|██████████| 4/4 [00:17<00:00,  4.39s/it]
# Найдено в поиске: 397
# Новых (ещё не в мастере): 0

# %%
# Функция загрузки данных по новым вакансиям

def fetchVacanciesDetails(ids, pause = 1.5, base_url = BASE_URL):
    rows = []
    for id in ids:
        r = requests.get(f"{base_url}/{id}")
        if r.status_code != 200:
            time.sleep(pause)
            continue
        v = r.json()

        key_skills = ", ".join([k.get("name") for k in (v.get("key_skills") or [])])

        desc_html = (v.get("description") or "")
        description = BeautifulSoup(desc_html, "html.parser").get_text(" ").strip()

        rows.append({
            "id": str(v.get("id")),
            "key_skills": key_skills,
            "description": description
        })
        time.sleep(pause)

        return pd.DataFrame(rows, columns=["id","key_skills","description"])

# %%
# функция сборки датасета из новых вакансий

def build_new_dataset(df_new_basic: pd.DataFrame) -> pd.DataFrame:
    # берём список новых id
    new_ids = df_new_basic["id"].astype(str).tolist()
    # тянем детали
    df_details = fetchVacanciesDetails(new_ids, pause=0.3)
    # объединяем
    if df_details.empty:
        # если деталей не получили (редко), вернём хотя бы basic с пустыми полями
        df_new_full = df_new_basic.copy()
        df_new_full["key_skills"] = ""
        df_new_full["description"] = ""
        return df_new_full

    df_new_full = (
        df_new_basic.astype({"id": str})
        .merge(df_details, on="id", how="left")
    )
    return df_new_full[["id","name","area","experience","key_skills","description"]]

# %%
# Добавление данных в мастер-файл

def append_to_master(df_new_full: pd.DataFrame, master_path=MASTER_PATH):
    ensureMaster(master_path)
    df_master = pd.read_csv(master_path, dtype=str)

    before = len(df_master)
    # конкат и удаление дубликатов по id
    df_updated = (
        pd.concat([df_master, df_new_full.astype(str)], ignore_index=True)
          .drop_duplicates(subset=["id"])
    )
    df_updated.to_csv(master_path, index=False, encoding="utf-8-sig")
    added = len(df_updated) - before
    print(f"Мастер обновлён: +{added} строк, всего {len(df_updated)} → {master_path}")
    return added

# %%
master_ids = getMasterIds()
df_basic = fetchVacansiesList(params, max_pages=20)
df_new_basic = filterNewIds(df_basic, master_ids)

if len(df_new_basic) > 0:
    df_new_full = build_new_dataset(df_new_basic)
    new_csv_path = saveVacanciesToCsv(df_new_full)         # (3.3)
    _added = append_to_master(df_new_full)           # (3.4)
else:
    print("Новых вакансий нет — шаг 3 пропущен.")
# Out:
# Мастер-файл найден: ..\data\raw_data\vacancies_master.csv
# Поиск: 100%|██████████| 4/4 [00:16<00:00,  4.13s/it]
# Новых вакансий нет — шаг 3 пропущен.

# %% [markdown]
# Парсер для необходимых данных готов. Перенесем код в отдельный скрипт
